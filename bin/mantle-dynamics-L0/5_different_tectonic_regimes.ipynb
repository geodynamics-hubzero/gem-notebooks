# %% [markdown]
# ## Onset of Convection
#
# As described in the previous notebook, Rayleigh number (Ra), describes the vigor of convection as :
#
# \begin{align}
#     Ra = \frac{\rho_0 g {\alpha}{\Delta}T D^3}{{\eta}k}
# \end{align}
#
# It is important to note that:
# * below a critical value for a fluid (for the Earth's mantle, $\sim$ 1000), the disturbances decay over time and the fluid layer does not convect. In this case, heat is transferred purely by conduction
# * above this ciritcal value, heat is transported by convection
#
# We can reformulate the above equation such that:
#
# \begin{align}
#     {\Delta}T = \frac{{\eta}k Ra_{crit}} {\rho_0 g {\alpha} D^3}
# \end{align}
#
# This suggests that a linear relationship exists between $\Delta T$ and $\eta$ for the line of onset of convection
#
# ### Tectonic Regimes
# Convection is linked closely to the lithospheric plates, however, it is possible that even with a high enough Ra, some planets do not have mobile plates.
#
# For planetary bodies to have plate tectonics, it is important that the convective stresses are larger than the yield stress of the lithosphere.  If the convective stresses are not enough to overcome the lithospheric yield stress, the planet's surface will not break to form plate boundaries and it may have no surface motion. These bodies exihibit *Stagnant lid convection* (e.g., present-day Mars and Venus). On the other hand, some planetary bodies may also have "heat pipe" regime, where the magma erupts to the surface in narrow vertical channels through the lithosphere, e.g., Io.
#
# The following figure illustrates some of the different tectonic regimes :
#
# <figure>
# <img src="images/mantle_convection_cell.png" width="400"/>
# <figcaption align = "center"> Image source: Anna Gülcher (2023) through  CC BY-NC-SA 4.0. </figcaption>
# </figure>
