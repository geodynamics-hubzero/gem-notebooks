# %% [markdown]
# ## What is ASPECT?
#
# ASPECT stands for the "Advanced Solver for Planetary Evolution, Convection, and Tectonics." ASPECT can solve for a wide range of physical processes occurring at different spatial and temporal scales inside the Earth's mantle. Consequently, it includes capabilities for viscous, visco-plastic, and elastoviscoplastic rheologies, melting, free surfaces, and more. More information about ASPECT and it's philosophy can be found in [this](https://github.com/geodynamics/aspect/blob/main/cookbooks/convection-box/tutorial-onset-of-convection/notebooks/tutorial_intro.ipynb) notebook.
#
# ### Using ASPECT
# ASPECT is a command line tool. ASPECT is driven by text-based input files which use the .prm extension. It outputs statistics files which can be visualized as well as file formats recognized by common visualizaition packages such as paraview. Using the command line tool, writing input files, and interpreting output files will be demonstrated later in this tutorial.
#
# ### Installation
# There are two ways to install/use ASPECT with this module:
#
# 1. [HUBZero environment with ASPECT](https://geodynamics.org/resources/tools): ASPECT and its dependencies are installed system-wide, and no other software needs to be installed. (**preferred option**)
#
# 2. Local installation in the machine where this module is run :
# There are a number of ways to install ASPECT. Please refer to the ASPECT [manual](https://aspect-documentation.readthedocs.io/en/latest/user/install/index.html) for help installing ASPECT.

# %% [markdown]
# ## ASPECT Parameter File
# ASPECT models are described through parameter files that determine: (i) discretization details, (ii) initial conditions, (iii) boundary conditions, and more. The following diagrams can help to think about the relationship between the input files and the ASPECT run as a whole.
#
# <figure>
# <img src="images/modular-1.png" width="400"/>
# <figcaption align = "center"> Image source: Wolfgang Bangerth, Juliane Dannberg , Menno Fraters, Rene Gassmoeller, Anne Glerum, Timo Heister, Lorraine Hwang, John Naliboff </figcaption>
# </figure>
#
# <figure>
# <img src="images/modular-2.png" width="400"/>
# <figcaption align = "center"> Image source: Wolfgang Bangerth, Juliane Dannberg , Menno Fraters, Rene Gassmoeller, Anne Glerum, Timo Heister, Lorraine Hwang, John Naliboff </figcaption>
# </figure>

# %% [markdown]
# ---------
#
# The following diagram highlights in red the elements of an ASPECT run which are described by the input files:
#
# <figure>
# <img src="images/aspect-6.png" width="400"/>
# <figcaption align = "center"> Image source: Wolfgang Bangerth, Juliane Dannberg , Menno Fraters, Rene Gassmoeller, Anne Glerum, Timo Heister, Lorraine Hwang, John Naliboff </figcaption>
# </figure>

# %% [markdown]
#  &nbsp;<div style="text-align: right">
#     &rarr; <b>NEXT: [Understanding the parameter file](./1-1_understanding_the_parameter_file.ipynb) </b> <a href=""></a> &nbsp;&nbsp;
#      <img src="../assets/education-gem-notebooks_icon.png" alt="icon"  style="width:4%">
#   </div>
