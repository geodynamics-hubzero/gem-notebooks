# %% [markdown]
# <p align="center"> <img src="assets/cig-logo.png" alt="cig icon" width="30%"> </p>
#
# <p align="center"> <img src="assets/education-gem-notebooks_icon.png" alt="icon" width="10%"> </p>
#
# <h1 style="text-align: center;">CIG-GEM Education Notebook</h1>
# <h1 style="text-align: center;">Rheology Module</h1>
#
# <h2 style="text-align: center;">Foundational Level (L0)</h2>
#
# <h3 style="text-align: center;">v0.1</h3>
# <h4 style="text-align: center;"> <small> <i> <b> Author: A. Saxena, Y. Jin, with contributions from the CIG Education Working Group</h3>
#
# [![License: GPLv3](https://img.shields.io/badge/License-GPLv3-blue)](LICENSE)

# %% [markdown]
# ## Description
#
# An introduction to rheology and its application in geodynamics. This module covers the fundamental concepts of rheology, including elastic, viscoelastic, viscous, and brittle behavior of materials. This module also explore how to interpret common geophysical observations in terms of the physical properties.
#
# ## Learning objectives
#
# ### Scientific
# Upon completion of this module you would be familiar with:
#
# - Brittle and ductile deformation
# - Viscoelastic deformation
# - Viscoplastic deformation
# - Viscous rheology under composite creep
# - Stokes sinker benchmark
#
#
# ### Technical
# Upon completion of this module you would be familiar with:
#
#  - PyVista for model output visualization
#  - the layout of Material Models in the model simulation files of ASPECT

# %% [markdown]
# ## Dependencies
# - Python (> version 3.3) with the following libraries installed:
#   * NumPy
#   * PyVista
#   * glob
#
# - ASPECT (> version 2.0) installed locally or using the ASPECT Jupyter notebook on the CIG HUBZero platform [here](https://geodynamics.org/resources/tools)

# %% [markdown]
# # Table of Contents
#
# - [Summary](./0_overview-rheology.ipynb)
#
# - [Viscoelastic deformation](./1_visco_elastic_deformation.ipynb)
#
# - [Viscoplastic deformation](./2_visco_plastic_deformation.ipynb)
#
# - [Composite rheology](./4_composite_rheology.ipynb)
#
# - [Modeling different deformation types](./5_modeling_viscous_elastic_plastic_deformation.ipynb)
#
# - [Plotting simulated deformation types](./6_plot_simulated_deformation_types.ipynb)
#
# - [Stokes benchmark](./7_stokes_flow_benchmark.ipynb)

# %% [markdown]
# ***
#
# ## References
#
# - Jonathan Turner; Turcotte, D. L. & Schubert, G. 2002. Geodynamics, 2nd ed.: xv + 456 pp. Cambridge, New York, Melbourne: Cambridge University Press. doi: https://doi.org/10.1017/S0016756802217239
# - Dannberg, J. 2020, GLY4450 Geophysics/GLY5455 Introduction to Geophysics [Lecture exercises], University of Florida

# %% [markdown]
#  &nbsp;<div style="text-align: right">
#     &rarr; <b>NEXT: [Deformation types](./1_deformation_types.ipynb) </b> <a href=""></a> &nbsp;&nbsp;
#      <img src="../assets/education-gem-notebooks_icon.png" alt="icon"  style="width:4%">
#   </div>
